# %%
"""
https://dotsnlines.tistory.com/894?category=1034801
위 블로그 소스 참고하여 내용 분석하고 소스코드를 다 고침
기존 코드는 너무 비효율적이라 시간도 많이 걸리고 excel 출력으로 구현되어 있어 빨리 확인하기 쉽지 않음
"""
from pykrx import stock
import pandas as pd
import numpy as np
import datetime
from dateutil.relativedelta import relativedelta
import os

pd.set_option('mode.chained_assignment',  None)

def row_pbr_company(date, years):
    """낮은 PBR 회사 20개의 투자 수익률 계산
    Args:
        date: 투자음    
        years: 투자기간
    Returns: DataFrame
        ticker 종목명 종가 상장주식수 PBR X년후종가 X년후상장주식수 상장주식수변동 pbr_rank 수익 수익률 투자년도
    """ 
    # code와 ticker이름을 먼저 구한다.
    start_date = stock.get_nearest_business_day_in_a_week(date=date) # 영업일
    codes = stock.get_market_ticker_list(start_date)
    
    # 투자 시작 시점 하위 PBR의 종가, 주식수 및 주요지표(PBR) 조회
    start_df_f = stock.get_market_fundamental_by_ticker(start_date)
    start_df_f = start_df_f[start_df_f['PBR'] > 0].sort_values(by=['PBR']).head(20) # PBR 0이상 하위 20개
    start_df_f.insert(0, '종목명', np.nan)
    for ticker in start_df_f.index.values:
        start_df_f.at[ticker, '종목명'] = stock.get_market_ticker_name(ticker)
    start_df_c = stock.get_market_cap_by_ticker(start_date)

    # 투자 종료 시점 종가, 주식수, 주요지표(PBR) 조회
    end_date = (datetime.datetime.strptime(date, '%Y%m%d') + relativedelta(years=years)).strftime('%Y%m%d')
    end_date = stock.get_nearest_business_day_in_a_week(date=end_date) # 영업일
    end_df_c = stock.get_market_cap_by_ticker(end_date)

    # 시작 시점과 종료 시점 데이터를 머지
    result_df = pd.merge(start_df_f, start_df_c, left_index=True, right_index=True)
    result_df = pd.merge(result_df, end_df_c, left_index=True, right_index=True)
    
    # 수익, 수익률 등을 계산하여 추가
    result_df['상장주식수변동'] = result_df['상장주식수_y'] - result_df['상장주식수_x']
    result_df['수익'] = result_df['종가_y'] - result_df['종가_x']
    # 주식수 변동(감소)에 따라 수익 수치 보정. 근데 증가는?
    # TODO 상장주식수가 증감하는 방식이 다양한데, 이걸로 수익률을 어떻게 계산할 수 있나? 유/무상 증자 등
    profit_df = result_df['종가_y'] * (1 + result_df['상장주식수변동'] / result_df['상장주식수_x']) - result_df['종가_x']
    result_df['수익'].loc[result_df['상장주식수변동'] < 0] = profit_df
    result_df['투자년도_x'] = np.array([start_date] * len(result_df))
    result_df['투자년도_y'] = np.array([end_date] * len(result_df))
    result_df['수익률'] = (result_df['수익'] / result_df['종가_x'])
    result_df = result_df.append(result_df.agg({'수익':['sum', 'mean'], '수익률':['sum', 'mean']}))

    return result_df

test_result = row_pbr_company('20190104', 1)
print(test_result)
# Out:
# C:\Users\sylee999\AppData\Local\Temp\ipykernel_27548\937273616.py:47: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result_df = result_df.append(result_df.agg({'수익':['sum', 'mean'], '수익률':['sum', 'mean']}))
#               종목명       BPS    PER   PBR       EPS   DIV     DPS     종가_x  \
# 071970     STX중공업   47208.0   0.02  0.11  264128.0  0.00     0.0   5210.0
# 011160       두산건설    9944.0   0.00  0.15       0.0  0.00     0.0   1480.0
# 002300       한국제지   99906.0   7.92  0.16    2040.0  1.86   300.0  16150.0
# 021820       세원정공   42284.0   0.00  0.16       0.0  1.48   100.0   6740.0
# 007860         서연   21594.0   0.00  0.17       0.0  2.72   100.0   3680.0
# 200880       서연이화   24673.0   3.54  0.18    1264.0  3.35   150.0   4480.0
# 000950         전방   88632.0   0.00  0.19       0.0  2.97   500.0  16850.0
# 058650      세아홀딩스  466950.0   2.75  0.20   33612.0  2.16  2000.0  92500.0
# 003030     세아제강지주  229348.0   9.43  0.20    4877.0  3.91  1800.0  46000.0
# 005010        휴스틸   54480.0  21.39  0.21     533.0  4.39   500.0  11400.0
# 005030       부산주공    2247.0   0.00  0.21       0.0  0.00     0.0    472.0
# 010100      한국프랜지    6832.0   0.00  0.21       0.0  0.00     0.0   1425.0
# 010690         화신   10100.0   0.00  0.23       0.0  2.14    50.0   2335.0
# 002220       한일철강   79035.0   3.57  0.24    5343.0  1.83   350.0  19100.0
# 012320     경동인베스트  149216.0   1.74  0.24   20799.0  1.38   500.0  36200.0
# 003480   한진중공업홀딩스   11219.0   0.00  0.24       0.0  0.00     0.0   2640.0
# 002820      SUN&L   21135.0   0.00  0.24       0.0  0.00     0.0   5040.0
# 016710      대성홀딩스   24992.0   4.81  0.25    1309.0  3.97   250.0   6290.0
# 001620  케이비아이동국실업    3298.0   0.00  0.25       0.0  0.00     0.0    824.0
# 006220       제주은행   18151.0   4.21  0.26    1101.0  2.16   100.0   4640.0
# sum           NaN       NaN    NaN   NaN       NaN   NaN     NaN      NaN
# mean          NaN       NaN    NaN   NaN       NaN   NaN     NaN      NaN
#
#               시가총액_x     거래량_x  ...     종가_y        시가총액_y     거래량_y  \
# 071970  1.463058e+11  137724.0  ...   3160.0  8.873827e+10  168293.0
# 011160  1.085226e+11   90769.0  ...   1395.0  4.602065e+11  209366.0
# 002300  8.082993e+10    3806.0  ...  17050.0  8.533438e+10   16812.0
# 021820  6.740000e+10    3310.0  ...   8090.0  8.090000e+10       0.0
# 007860  8.640583e+10   20874.0  ...   3290.0  7.724869e+10  598394.0
# 200880  1.210874e+11  182085.0  ...   5100.0  1.378450e+11   90843.0
# 000950  2.830800e+10     580.0  ...  15650.0  2.629200e+10     863.0
# 058650  3.700000e+11     599.0  ...  78900.0  3.156000e+11    2831.0
# 003030  1.455302e+11    6861.0  ...  47150.0  1.952791e+11    6432.0
# 005010  8.589727e+10   15660.0  ...   9990.0  7.614046e+10    8653.0
# 005030  1.998898e+10   82556.0  ...    478.0  2.025839e+10  145450.0
# 010100  4.339185e+10   47614.0  ...   2275.0  6.927471e+10  324068.0
# 010690  8.153916e+10   20016.0  ...   3425.0  1.196024e+11   39921.0
# 002220  4.263565e+10     466.0  ...   2025.0  4.520272e+10   13727.0
# 012320  8.561383e+10    5938.0  ...  36750.0  8.691460e+10    2650.0
# 003480  7.795870e+10   52913.0  ...   2610.0  7.707281e+10   17611.0
# 002820  6.354426e+10   10632.0  ...   4405.0  5.553819e+10    8203.0
# 016710  1.012027e+11    6529.0  ...   8240.0  1.325771e+11   14329.0
# 001620  4.392915e+10   98245.0  ...    710.0  4.688987e+10  184869.0
# 006220  1.490775e+11   16022.0  ...   4040.0  1.298002e+11    6496.0
# sum              NaN       NaN  ...      NaN           NaN       NaN
# mean             NaN       NaN  ...      NaN           NaN       NaN
#
#               거래대금_y      상장주식수_y      상장주식수변동        수익    투자년도_x    투자년도_y  \
# 071970  5.368710e+08   28081731.0          0.0  -2050.00  20190104  20200103
# 011160  2.944222e+08  329897110.0  256571021.0    -85.00  20190104  20200103
# 002300  2.870497e+08    5004949.0          0.0    900.00  20190104  20200103
# 021820  0.000000e+00   10000000.0          0.0   1350.00  20190104  20200103
# 007860  1.939633e+09   23479844.0          0.0   -390.00  20190104  20200103
# 200880  4.644003e+08   27028437.0          0.0    620.00  20190104  20200103
# 000950  1.331695e+07    1680000.0          0.0  -1200.00  20190104  20200103
# 058650  2.222894e+08    4000000.0          0.0 -13600.00  20190104  20200103
# 003030  3.038548e+08    4141657.0     977957.0   1150.00  20190104  20200103
# 005010  8.631627e+07    7621668.0      86820.0  -1410.00  20190104  20200103
# 005030  6.921617e+07   42381579.0      32051.0      6.00  20190104  20200103
# 010100  7.409014e+08   30450420.0          0.0    850.00  20190104  20200103
# 010690  1.362794e+08   34920410.0          0.0   1090.00  20190104  20200103
# 002220  2.766986e+07   22322330.0   20090097.0 -17075.00  20190104  20200103
# 012320  9.708355e+07    2365023.0          0.0    550.00  20190104  20200103
# 003480  4.558092e+07   29529812.0          0.0    -30.00  20190104  20200103
# 002820  3.597736e+07   12607989.0          0.0   -635.00  20190104  20200103
# 016710  1.179201e+08   16089459.0          0.0   1950.00  20190104  20200103
# 001620  1.327941e+08   66042072.0   12730000.0   -114.00  20190104  20200103
# 006220  2.630712e+07   32128774.0          0.0   -600.00  20190104  20200103
# sum              NaN          NaN          NaN -28723.00       NaN       NaN
# mean             NaN          NaN          NaN  -1436.15       NaN       NaN
#
#              수익률
# 071970 -0.393474
# 011160 -0.057432
# 002300  0.055728
# 021820  0.200297
# 007860 -0.105978
# 200880  0.138393
# 000950 -0.071217
# 058650 -0.147027
# 003030  0.025000
# 005010 -0.123684
# 005030  0.012712
# 010100  0.596491
# 010690  0.466809
# 002220 -0.893979
# 012320  0.015193
# 003480 -0.011364
# 002820 -0.125992
# 016710  0.310016
# 001620 -0.138350
# 006220 -0.129310
# sum    -0.377168
# mean   -0.018858
#
# [22 rows x 22 columns]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python310\site-packages\IPython\core\async_helpers.py:129, in _pseudo_sync_runner(coro)
#     121 """
#     122 A runner that does not really allow async execution, and just advance the coroutine.
#     123
#    (...)
#     126 Credit to Nathaniel Smith
#     127 """
#     128 try:
# --> 129     coro.send(None)
#     130 except StopIteration as exc:
#     131     return exc.value
#
# File ~\AppData\Roaming\Python\Python310\site-packages\IPython\core\interactiveshell.py:3135, in InteractiveShell.run_cell_async(self, raw_cell, store_history, silent, shell_futures, transformed_cell, preprocessing_exc_tuple, cell_id)
#    3132 # Execute the user code
#    3133 interactivity = "none" if silent else self.ast_node_interactivity
# -> 3135 has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#    3136        interactivity=interactivity, compiler=compiler, result=result)
#    3138 self.last_execution_succeeded = not has_raised
#    3139 self.last_execution_result = result
#
# File ~\AppData\Roaming\Python\Python310\site-packages\IPython\core\interactiveshell.py:3135, in InteractiveShell.run_cell_async(self, raw_cell, store_history, silent, shell_futures, transformed_cell, preprocessing_exc_tuple, cell_id)
#    3132 # Execute the user code
#    3133 interactivity = "none" if silent else self.ast_node_interactivity
# -> 3135 has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#    3136        interactivity=interactivity, compiler=compiler, result=result)
#    3138 self.last_execution_succeeded = not has_raised
#    3139 self.last_execution_result = result
#
# File _pydevd_bundle/pydevd_cython.pyx:1508, in _pydevd_bundle.pydevd_cython.trace_dispatch()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\debugpy\_vendored\pydevd\pydevd.py:1086, in PyDB.enable_tracing(self, thread_trace_func, apply_to_all_threads)
#    1083     else:
#    1084         self._local_thread_trace_func.thread_trace_func = thread_trace_func
# -> 1086 pydevd_tracing.SetTrace(thread_trace_func)
#    1087 if IS_CPYTHON and apply_to_all_threads:
#    1088     pydevd_tracing.set_trace_to_threads(thread_trace_func)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\debugpy\_vendored\pydevd\pydevd_tracing.py:77, in SetTrace(tracing_func)
#      74 _last_tracing_func_thread_local.tracing_func = tracing_func
#      76 if tracing_func is not None:
# ---> 77     if set_trace_to_threads(tracing_func, thread_idents=[thread.get_ident()], create_dummy_thread=False) == 0:
#      78         # If we can use our own tracer instead of the one from sys.settrace, do it (the reason
#      79         # is that this is faster than the Python version because we don't call
#      80         # PyFrame_FastToLocalsWithError and PyFrame_LocalsToFast at each event!
#      81         # (the difference can be huge when checking line events on frames as the
#      82         # time increases based on the number of local variables in the scope)
#      83         # See: InternalCallTrampoline (on the C side) for details.
#      84         return
#      86 # If it didn't work (or if it was None), use the Python version.
#
# File ~\AppData\Roaming\Python\Python310\site-packages\debugpy\_vendored\pydevd\pydevd_tracing.py:345, in set_trace_to_threads(tracing_func, thread_idents, create_dummy_thread)
#     343 start_new_thread = pydev_monkey.get_original_start_new_thread(thread)
#     344 start_new_thread(increase_tracing_count, ())
# --> 345 proceed.acquire()  # Only proceed after the release() is done.
#     346 proceed = None
#     348 # Note: The set_trace_func is not really used anymore in the C side.
#
# KeyboardInterrupt:
